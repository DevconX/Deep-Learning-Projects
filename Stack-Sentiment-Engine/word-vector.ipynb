# %%
import tensorflow as tf
import numpy as np
import time
import os
import collections
import random
import time

# %%
def build_dataset(words, n_words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    global data
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            for word in data[:span]:
                buffer.append(word)
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
import pickle
with open('dataset.p', 'rb') as fopen:
    dataset=pickle.load(fopen)

# %%
vocabulary=(' '.join(dataset[:,1].tolist())).split()
print('example 10 words:',vocabulary[:10])
print('size corpus:',len(vocabulary))
vocabulary_size = len(list(set(vocabulary)))
print('size of unique words:',vocabulary_size)
dimension = 128
skip_window = 1
num_skips = 2
batch_size = 64
location = os.getcwd()
# Out:
# example 10 words: ['retailers', 'restaurants', 'schools', 'hospitals', 'also', 'added', 'jobs', 'brisk', 'pace', 'according']
# size corpus: 315018
# size of unique words: 21022

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 1], ('said', 3130), ('percent', 2509), ('market', 2446), ('year', 2128)]
# Sample data [656, 4813, 1971, 4358, 36, 173, 82, 2640, 186, 136] ['retailers', 'restaurants', 'schools', 'hospitals', 'also', 'added', 'jobs', 'brisk', 'pace', 'according']

# %%
valid_size = 16
valid_window = 100
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
graph = tf.Graph()

with graph.as_default():

    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, dimension], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)
        nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, dimension],
                                                      stddev=1.0 / np.sqrt(dimension)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
        loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights,
                                             biases=nce_biases,
                                             labels=train_labels,
                                             inputs=embed,
                                             num_sampled=batch_size / 2,
                                             num_classes=vocabulary_size))
        optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)
        init = tf.global_variables_initializer()

num_steps = 300000

# %%
with tf.Session(graph=graph) as session:
    init.run()
    print('Initialized')

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  142.486282349
# Nearest to higher: nonprofits, easiest, sport-utility, atement, straphangers, geography, extreme, less-stimulative,
# Nearest to economic: inspires, liberalizations, bowen, crest, hotly, wrapped, teton, intangibilityrespect,
# Nearest to months: mid-s, dorrow, negro, belie, reaffirmed, trillion, sync, -nation,
# Nearest to consumer: now-useless, kennedy, mid-six-lies, glimmer, lies, keating, dormant, sanders,
# Nearest to rate: voted, stumbling, keyboard, rino, lobust, arthrocare, socially, sadly,
# Nearest to trading: khedouri, lighter, undervalued, squarely, frost, modestly, director, widely,
# Nearest to recent: hispanic, figured, drugs, resoundingly, cautious, defying, trillion, supplied,
# Nearest to economists: roust, laggards, intraday, thomas, compensatory, relies, easily, feeds,
# Nearest to rise: retroactive, ineffective, differentials, brake, narrowed, formulate, cheaply, lapping,
# Nearest to sales: translate, nonfood, lambs, home-loan, intend, outstanding, chapters, unnerve,
# Nearest to securities: select, endicott, de-partment, broker-dealers, affair, santomero, faces, malls,
# Nearest to reserve: upgraded, richfield, familiarculminating, dimension, satisfying, hideo, gintel, philco,
# Nearest to funds: pause, step, probably, outearned, budget-busting, practical, drimcgraw-hill, taft,
# Nearest to industrial: co-head, appropriations, oppenhei-mer, ucla, immune, high, edged, hsinhua,
# Nearest to government: includes, reflects, onesbut, redemptions, galvin, handsomely, reassured, kirkland,
# Nearest to price: counties, factory, sanpaolo, rationing, elsenhowers, august, dnt-, supermarkets,
# Average loss at step  2000 :  61.1031154487
# Average loss at step  4000 :  27.6369127789
# Average loss at step  6000 :  17.216586972
# Average loss at step  8000 :  12.6856788595
# Average loss at step  10000 :  10.3403886892
# Nearest to higher: climate, suburbs, straphangers, organizations, utah, fell, extreme, likelihood,
# Nearest to economic: economy, predicted, require, crest, obviously, kept, rebounded, said,
# Nearest to months: mid-s, days, districts, negro, slowdown, glass, empty, years,
# Nearest to consumer: kennedy, lies, deposit, discounting, dormant, slid, thoughts, squeezed,
# Nearest to rate: percent, voted, finish, started, nixon, rates, perking, cheer,
# Nearest to trading: widely, undervalued, modestly, flowing, retreated, weighed, khedouri, soaring,
# Nearest to recent: suggest, trillion, drugs, hispanic, ment, heaviest, deposited, supplied,
# Nearest to economists: analysts, easily, harriman, intraday, thomas, obligations, economy, toll,
# Nearest to rise: retroactive, population, details, narrowed, brake, rose, weekend, fallen,
# Nearest to sales: encourage, minor, translate, stocks, outstanding, west, occur, one-year,
# Nearest to securities: select, playing, faces, broker-dealers, expect, coupled, recover, healthier,
# Nearest to reserve: inversion, dimension, questions, smallest, neither, matters, accelerating, aspect,
# Nearest to funds: pause, hovering, urge, merchandisers, hoping, step, filed, unlikely,
# Nearest to industrial: edged, supply-side, fifty, immune, computer, restraint, yields, industrials,
# Nearest to government: trillion, unlike, reflects, includes, briefly, vietnam, spurt, well,
# Nearest to price: italy, finnegan, august, exports, dealer, came, supply-side, interest-rate,
# Average loss at step  12000 :  7.72324211001
# Average loss at step  14000 :  6.32891458118
# Average loss at step  16000 :  5.7642762984
# Average loss at step  18000 :  5.36287582302
# Average loss at step  20000 :  5.1288525461
# Nearest to higher: straphangers, climate, rising, suburbs, lower, gasoline, fell, boeing,
# Nearest to economic: economy, crest, require, jump-start, college, irving, ominous, conferees,
# Nearest to months: days, years, mid-s, year, week, reaffirmed, month, districts,
# Nearest to consumer: kennedy, lies, allowance, now-useless, dormant, deposit, discounting, after-tax,
# Nearest to rate: percent, finish, rates, sadly, voted, nixon, perking, started,
# Nearest to trading: khedouri, buoying, flowing, undervalued, performances, burned, lighter, widely,
# Nearest to recent: suggest, heaviest, hispanic, trillion, resoundingly, ment, drugs, five,
# Nearest to economists: analysts, harriman, easily, pictures, obligations, giordano, thomas, laggards,
# Nearest to rise: population, retroactive, decline, drop, rose, fallen, rising, studios,
# Nearest to sales: nexus, endanger, encourage, hovering, minor, prices, northeastern, one-year,
# Nearest to securities: select, playing, healthier, faces, four-part, broker-dealers, sponsorship, penney,
# Nearest to reserve: inversion, dimension, upgraded, staple, confronts, resorts, muster, aspect,
# Nearest to funds: pause, hovering, merchandisers, urge, practical, outearned, subprime, step,
# Nearest to industrial: fifty, edged, supply-side, industrials, pull, issuing, reliable, appropriations,
# Nearest to government: trillion, unlike, troubles, perts, briefly, notice, reflects, wildly,
# Nearest to price: solemnly, finnegan, italy, supply-side, dealer, august, poses, concrete,
# Average loss at step  22000 :  4.55028401566
# Average loss at step  24000 :  4.27070820093
# Average loss at step  26000 :  4.14928839946
# Average loss at step  28000 :  4.09462727785
# Average loss at step  30000 :  4.02992878437
# Nearest to higher: lower, rising, straphangers, suburbs, gasoline, climate, per-share, fell,
# Nearest to economic: economy, ominous, northern, lets-get-ours-now, intend, irving, crest, sprawling,
# Nearest to months: days, years, month, year, mid-s, week, downgraded, notch,
# Nearest to consumer: kennedy, now-useless, allowance, lies, weinberg, atmospheric, keating, discounting,
# Nearest to rate: percent, rates, sadly, finish, nixon, perking, cent, voted,
# Nearest to trading: buoying, khedouri, performances, burned, billings, undervalued, flowing, lighter,
# Nearest to recent: resoundingly, heaviest, hispanic, suggest, five, ment, trillion, crummy,
# Nearest to economists: analysts, pictures, princeton, harriman, located, easily, stalemate, obligations,
# Nearest to rise: drop, decline, population, retroactive, increase, fallen, pepperdine, rose,
# Nearest to sales: endanger, nexus, hovering, encourage, northeastern, octo-ber-to-december, waged, leventhals,
# Nearest to securities: select, four-part, stock, playing, healthier, logically, sponsorship, abby,
# Nearest to reserve: dimension, inversion, resorts, reserves, confronts, second-half, grips, staple,
# Nearest to funds: pause, hovering, subprime, merchandisers, practical, dismantled, outearned, examined,
# Nearest to industrial: fifty, industrials, alpha, edged, ucla, issuing, supply-side, pull,
# Nearest to government: trillion, perts, notice, troubles, unlike, briefly, dents, yesterday,
# Nearest to price: solemnly, finnegan, sharp, concrete, supply-side, dnt-, dealer, interest-rate,
# Average loss at step  32000 :  3.86266837323
# Average loss at step  34000 :  3.76576726425
# Average loss at step  36000 :  3.73528031695
# Average loss at step  38000 :  3.70020516396
# Average loss at step  40000 :  3.70186325252
# Nearest to higher: lower, rising, straphangers, sport-utility, per-share, suburbs, gasoline, fell,
# Nearest to economic: economy, lets-get-ours-now, torvormayororyt, sprawling, northern, policysetting, intend, irving,
# Nearest to months: years, days, month, year, downgraded, mid-s, recessions, week,
# Nearest to consumer: kennedy, allowance, now-useless, atmospheric, weinberg, keating, lies, dormant,
# Nearest to rate: percent, rates, sadly, finish, greedy, perking, cent, kilman,
# Nearest to trading: buoying, performances, khedouri, billings, burned, flowing, romney, lighter,
# Nearest to recent: resoundingly, heaviest, hispanic, five, ment, disbelief, aside, crummy,
# Nearest to economists: analysts, pictures, observers, mccarthy, princeton, harriman, giordano, seeing,
# Nearest to rise: drop, decline, increase, population, retroactive, rising, climb, fall,
# Nearest to sales: endanger, nexus, exports, sjaid, octo-ber-to-december, waged, hovering, leventhals,
# Nearest to securities: select, logically, stock, bonds, four-part, penney, healthier, playing,
# Nearest to reserve: dimension, reserves, confronts, second-half, resorts, muster, inversion, grips,
# Nearest to funds: pause, servicer, hovering, subprime, dismantled, practical, merchandisers, examined,
# Nearest to industrial: fifty, industrials, alpha, studded, mindset, combined, lone, danish,
# Nearest to government: trillion, perts, notice, unlike, ramirez, dents, brushed, troubles,
# Nearest to price: solemnly, sharp, concrete, dnt-, finnegan, dealer, whipsaw, interest-rate,
# Average loss at step  42000 :  3.61640396178
# Average loss at step  44000 :  3.58337484741
# Average loss at step  46000 :  3.54703198516
# Average loss at step  48000 :  3.53917959368
# Average loss at step  50000 :  3.53142368519
# Nearest to higher: rising, lower, sport-utility, suburbs, straphangers, per-share, gasoline, less-stimulative,
# Nearest to economic: economy, torvormayororyt, policysetting, lets-get-ours-now, precursor, unsecured, northern, intend,
# Nearest to months: years, days, month, downgraded, year, week, dimmed, silvia,
# Nearest to consumer: kennedy, allowance, now-useless, weinberg, atmospheric, ammunition, overtake, dormant,
# Nearest to rate: percent, rates, sadly, kilman, muggy, finish, executions, wrangling,
# Nearest to trading: buoying, performances, khedouri, billings, romney, burned, lighter, flowing,
# Nearest to recent: resoundingly, heaviest, aside, disbelief, hispanic, ment, redeem, crummy,
# Nearest to economists: analysts, observers, mccarthy, pictures, princeton, traders, seeing, manufacturing-intensive,
# Nearest to rise: drop, increase, decline, population, climb, rising, fall, retroactive,
# Nearest to sales: endanger, waged, prices, exports, sjaid, eight-tenths, leventhals, northeastern,
# Nearest to securities: logically, select, four-part, bonds, abby, penney, levelling, healthier,
# Nearest to reserve: dimension, reserves, second-half, confronts, resorts, muster, neither, regulators,
# Nearest to funds: servicer, pause, subprime, hovering, assures, dismantled, outearned, two-to-one,
# Nearest to industrial: industrials, fifty, alpha, mindset, studded, combined, -stock, ucla,
# Nearest to government: perts, trillion, notice, brushed, marketed, unlike, fireworks, dents,
# Nearest to price: solemnly, concrete, sharp, interest-rate, dnt-, whipsaw, finnegan, dealer,
# Average loss at step  52000 :  3.48019643998
# Average loss at step  54000 :  3.45899602211
# Average loss at step  56000 :  3.41983771098
# Average loss at step  58000 :  3.41523642695
# Average loss at step  60000 :  3.41679742813
# Nearest to higher: rising, lower, per-share, sport-utility, suburbs, straphangers, fredric, ruin,
# Nearest to economic: policysetting, northern, precursor, economy, torvormayororyt, intend, sprawling, lets-get-ours-now,
# Nearest to months: years, days, month, downgraded, year, week, unhappy, silvia,
# Nearest to consumer: allowance, weinberg, now-useless, kennedy, ammunition, wound, atmospheric, charlotte,
# Nearest to rate: percent, sadly, rates, kilman, muggy, rale, leven-thal, finish,
# Nearest to trading: buoying, performances, billings, khedouri, romney, flowing, supports, burned,
# Nearest to recent: disbelief, resoundingly, heaviest, aside, hispanic, ment, crummy, four,
# Nearest to economists: analysts, observers, pictures, princeton, mccarthy, announces, traders, manufacturing-intensive,
# Nearest to rise: drop, increase, decline, climb, rising, fall, population, retroactive,
# Nearest to sales: endanger, prices, waged, eight-tenths, leventhals, exports, irin, octo-ber-to-december,
# Nearest to securities: logically, bonds, four-part, select, bond, penney, levelling, solving,
# Nearest to reserve: second-half, reserves, regulators, resorts, dimension, hist, perking, confronts,
# Nearest to funds: servicer, pause, assures, subprime, hovering, individual, dismantled, affiliation,
# Nearest to industrial: industrials, fifty, mindset, -stock, alpha, combined, rail, studded,
# Nearest to government: perts, notice, brushed, trillion, marketed, unlike, dents, fireworks,
# Nearest to price: solemnly, dnt-, concrete, whipsaw, sharp, interest-rate, sticks, prices,
# Average loss at step  62000 :  3.36727798319
# Average loss at step  64000 :  3.35990247011
# Average loss at step  66000 :  3.32064912069
# Average loss at step  68000 :  3.31899557638
# Average loss at step  70000 :  3.32909348422
# Nearest to higher: rising, lower, suburbs, per-share, sport-utility, straphangers, vied, ruin,
# Nearest to economic: precursor, northern, unsecured, torvormayororyt, sprawling, policysetting, economy, pro-gram,
# Nearest to months: years, days, month, downgraded, unhappy, decades, silvia, wood,
# Nearest to consumer: ammunition, weinberg, now-useless, allowance, wound, slid, atmospheric, producer,
# Nearest to rate: rates, sadly, percent, muggy, kilman, rale, realty, rodriguez,
# Nearest to trading: buoying, performances, billings, khedouri, romney, flowing, burned, supports,
# Nearest to recent: disbelief, aside, heaviest, four, resoundingly, hispanic, crummy, redeem,
# Nearest to economists: analysts, observers, pictures, princeton, mccarthy, adjustmentthe, forecasters, some,
# Nearest to rise: drop, increase, decline, climb, fall, rising, population, retroactive,
# Nearest to sales: prices, endanger, eight-tenths, waged, irin, heavy-duty, sjaid, contemplate,
# Nearest to securities: logically, bonds, four-part, penney, select, solving, remembered, levelling,
# Nearest to reserve: second-half, reserves, regulators, hist, perking, dimension, resorts, confronts,
# Nearest to funds: servicer, assures, hovering, pause, contemplates, subprime, dismantled, mindspring,
# Nearest to industrial: industrials, fifty, mindset, -stock, combined, alpha, rail, studded,
# Nearest to government: perts, notice, brushed, trillion, scrambled, unlike, marketed, dents,
# Nearest to price: solemnly, dnt-, whipsaw, concrete, finnegan, larger-than-expected, dealer, interest-rate,
# Average loss at step  72000 :  3.2711410237
# Average loss at step  74000 :  3.27668688202
# Average loss at step  76000 :  3.23523526895
# Average loss at step  78000 :  3.23416298664
# Average loss at step  80000 :  3.2501906839
# Nearest to higher: rising, lower, suburbs, per-share, sport-utility, straphangers, fredric, landline,
# Nearest to economic: precursor, unsecured, policysetting, intend, lets-get-ours-now, northern, torvormayororyt, sprawling,
# Nearest to months: years, month, downgraded, days, unhappy, decades, year, hefty,
# Nearest to consumer: ammunition, weinberg, producer, now-useless, wound, slid, allowance, atmospheric,
# Nearest to rate: percent, sadly, rates, rale, kilman, muggy, rodriguez, ryding,
# Nearest to trading: performances, buoying, khedouri, billings, advertisers, lighter, pernaps, flowing,
# Nearest to recent: disbelief, heaviest, aside, crummy, soothed, resoundingly, hispanic, four,
# Nearest to economists: analysts, observers, pictures, forecasters, some, manufacturing-intensive, adjustmentthe, princeton,
# Nearest to rise: drop, increase, fall, decline, climb, rising, population, retroactive,
# Nearest to sales: endanger, waged, prices, irin, contemplate, heavy-duty, leventhals, second-quarter,
# Nearest to securities: logically, bonds, select, solving, santomero, penney, remembered, thoughtful,
# Nearest to reserve: regulators, second-half, resorts, hist, dimension, reserves, perking, confronts,
# Nearest to funds: servicer, hovering, individual, assures, subprime, tradpr, dismantled, pause,
# Nearest to industrial: industrials, fifty, combined, mindset, -stock, rail, studded, alpha,
# Nearest to government: perts, notice, brushed, marketed, unlike, scrambled, ramirez, trillion,
# Nearest to price: solemnly, dnt-, concrete, whipsaw, larger-than-expected, interest-rate, finnegan, sticks,
# Average loss at step  82000 :  3.19166199785
# Average loss at step  84000 :  3.20051299566
# Average loss at step  86000 :  3.15223862445
# Average loss at step  88000 :  3.16273132432
# Average loss at step  90000 :  3.17562080562
# Nearest to higher: rising, lower, per-share, suburbs, sport-utility, modular, straphangers, ruin,
# Nearest to economic: precursor, lets-get-ours-now, unsecured, policysetting, northern, sprawling, pro-gram, stone,
# Nearest to months: years, days, downgraded, month, decades, unhappy, weeks, silvia,
# Nearest to consumer: ammunition, weinberg, allowance, producer, now-useless, slid, wound, atmospheric,
# Nearest to rate: rates, sadly, percent, rale, executions, kilman, muggy, finish,
# Nearest to trading: buoying, performances, billings, khedouri, flowing, mitt, advertisers, pernaps,
# Nearest to recent: disbelief, heaviest, aside, crummy, posed, soothed, four, correlated,
# Nearest to economists: analysts, observers, forecasters, pictures, some, galvanized, manufacturing-intensive, princeton,
# Nearest to rise: drop, increase, decline, climb, fall, rising, retroactive, population,
# Nearest to sales: endanger, prices, waged, irin, contemplate, octo-ber-to-december, heavy-duty, framework,
# Nearest to securities: logically, bonds, solving, remembered, select, santomero, thoughtful, twenty,
# Nearest to reserve: regulators, hist, second-half, confronts, resorts, reserves, questions, dimension,
# Nearest to funds: servicer, individual, hovering, subprime, assures, tradpr, contemplates, labyrinth,
# Nearest to industrial: industrials, fifty, combined, -stock, mindset, rail, studded, anti-climax,
# Nearest to government: perts, brushed, notice, marketed, dents, scrambled, unlike, trillion,
# Nearest to price: solemnly, dnt-, whipsaw, concrete, larger-than-expected, sticks, sharp, interest-rate,
# Average loss at step  92000 :  3.13483540112
# Average loss at step  94000 :  3.13644749981
# Average loss at step  96000 :  3.09720442224
# Average loss at step  98000 :  3.10535270256
# Average loss at step  100000 :  3.10903804255
# Nearest to higher: rising, lower, per-share, suburbs, sport-utility, ilmited, landline, shuffled,
# Nearest to economic: policysetting, precursor, northern, lets-get-ours-now, visits, pro-gram, candidacy, discrimination,
# Nearest to months: years, downgraded, month, days, unhappy, turreted, wood, notch,
# Nearest to consumer: producer, ammunition, weinberg, slid, allowance, now-useless, wound, overtake,
# Nearest to rate: rates, sadly, rale, kilman, percent, rodriguez, executions, muggy,
# Nearest to trading: buoying, performances, billings, khedouri, romney, pernaps, flowing, mitt,
# Nearest to recent: heaviest, aside, disbelief, posed, soothed, preceding, smooths, automobilesinspired,
# Nearest to economists: analysts, observers, forecasters, some, adjustmentthe, pictures, galvanized, princeton,
# Nearest to rise: drop, increase, fall, climb, decline, retroactive, rising, loss,
# Nearest to sales: endanger, irin, eight-tenths, richly, waged, heavy-duty, fearful, second-quarter,
# Nearest to securities: logically, bonds, thoughtful, santomero, solving, select, bond, remembered,
# Nearest to reserve: regulators, hist, second-half, confronts, exerts, dimension, perking, questions,
# Nearest to funds: servicer, individual, tradpr, subprime, assures, contemplates, labyrinth, hovering,
# Nearest to industrial: industrials, fifty, combined, -stock, mindset, anti-climax, studded, rail,
# Nearest to government: perts, brushed, notice, marketed, unlike, scrambled, ramirez, dents,
# Nearest to price: solemnly, dnt-, larger-than-expected, concrete, whipsaw, sticks, pointshigher, fashioning,
# Average loss at step  102000 :  3.07033285874
# Average loss at step  104000 :  3.08905344069
# Average loss at step  106000 :  3.03890723646
# Average loss at step  108000 :  3.0467724303
# Average loss at step  110000 :  3.05925275367
# Nearest to higher: rising, lower, suburbs, per-share, sport-utility, ilmited, ultralow, shuffled,
# Nearest to economic: policysetting, lets-get-ours-now, precursor, northern, unsecured, visits, pro-gram, vanished,
# Nearest to months: years, downgraded, month, days, unhappy, wood, declines, decades,
# Nearest to consumer: ammunition, producer, allowance, slid, weinberg, atmospheric, wholesale, wound,
# Nearest to rate: percent, rates, rale, sadly, rodriguez, butwith, kilman, executions,
# Nearest to trading: buoying, performances, billings, khedouri, romney, pernaps, mitt, equity-linked,
# Nearest to recent: disbelief, aside, posed, preceding, smooths, heaviest, soothed, rewriting,
# Nearest to economists: analysts, observers, forecasters, pictures, princeton, manufacturing-intensive, adjustmentthe, galvanized,
# Nearest to rise: drop, increase, fall, climb, decline, retroactive, rising, loss,
# Nearest to sales: prices, endanger, waged, richly, irin, contemplate, eight-tenths, heavy-duty,
# Nearest to securities: logically, bonds, remembered, santomero, solving, penney, thoughtful, continuously,
# Nearest to reserve: regulators, hist, second-half, confronts, exerts, questions, dimension, perking,
# Nearest to funds: servicer, individual, tradpr, labyrinth, contemplates, subprime, assures, mightiest,
# Nearest to industrial: industrials, fifty, -stock, combined, anti-climax, mindset, studded, rail,
# Nearest to government: perts, brushed, notice, marketed, scrambled, unlike, ramirez, longest-serving,
# Nearest to price: dnt-, larger-than-expected, solemnly, concrete, whipsaw, sticks, prices, pointshigher,
# Average loss at step  112000 :  3.01554586422
# Average loss at step  114000 :  3.03037379062
# Average loss at step  116000 :  2.99104220992
# Average loss at step  118000 :  2.99410436606
# Average loss at step  120000 :  3.00147386873
# Nearest to higher: lower, rising, per-share, suburbs, sport-utility, ultralow, ilmited, shuffled,
# Nearest to economic: precursor, candidacy, policysetting, lets-get-ours-now, northern, unsecured, sprawling, feasting,
# Nearest to months: years, downgraded, month, days, wood, decades, unhappy, year,
# Nearest to consumer: ammunition, producer, weinberg, slid, overtake, wound, atmospheric, rolling,
# Nearest to rate: rates, rodriguez, percent, sadly, rale, muggy, butwith, militar,
# Nearest to trading: performances, buoying, billings, khedouri, pernaps, romney, flowing, mitt,
# Nearest to recent: posed, preceding, disbelief, heaviest, soothed, smooths, copycat, confusing,
# Nearest to economists: analysts, observers, forecasters, pictures, galvanized, some, manufacturing-intensive, chieftains,
# Nearest to rise: drop, increase, fall, climb, decline, retroactive, rising, loss,
# Nearest to sales: waged, heavy-duty, richly, contemplate, eight-tenths, fearful, irin, endanger,
# Nearest to securities: logically, remembered, santomero, solving, bonds, select, continuously, thoughtful,
# Nearest to reserve: hist, regulators, second-half, perking, tax-selling, confronts, dimension, questions,
# Nearest to funds: servicer, individual, tradpr, assures, labyrinth, subprime, mindspring, unacceptably,
# Nearest to industrial: industrials, fifty, combined, -stock, anti-climax, mindset, rail, studded,
# Nearest to government: perts, brushed, marketed, notice, scrambled, ramirez, fireworks, dents,
# Nearest to price: dnt-, larger-than-expected, concrete, solemnly, whipsaw, sticks, portends, stretches,
# Average loss at step  122000 :  2.96505554318
# Average loss at step  124000 :  2.99034135443
# Average loss at step  126000 :  2.95305174154
# Average loss at step  128000 :  2.94611819774
# Average loss at step  130000 :  2.96991160727
# Nearest to higher: lower, rising, suburbs, per-share, sport-utility, shuffled, ilmited, eye-opener,
# Nearest to economic: precursor, lets-get-ours-now, policysetting, visits, pectations, northern, sprawling, candidacy,
# Nearest to months: years, downgraded, month, days, silvia, empty, unhappy, wood,
# Nearest to consumer: producer, ammunition, retail, atmospheric, weinberg, sends, wholesale, slid,
# Nearest to rate: rates, sadly, rale, percent, rodriguez, executions, five-tenths, realty,
# Nearest to trading: performances, buoying, pernaps, billings, romney, khedouri, mitt, flowing,
# Nearest to recent: disbelief, preceding, posed, smooths, heaviest, confusing, soothed, automobilesinspired,
# Nearest to economists: analysts, observers, forecasters, galvanized, manufacturing-intensive, pictures, some, chieftains,
# Nearest to rise: drop, increase, fall, climb, retroactive, decline, rising, steadier,
# Nearest to sales: irin, richly, heavy-duty, contemplate, eight-tenths, endanger, prices, waged,
# Nearest to securities: logically, select, remembered, continuously, twenty, santomero, levelling, bonds,
# Nearest to reserve: second-half, regulators, hist, perking, dimension, questions, penfield, tax-selling,
# Nearest to funds: servicer, individual, tradpr, labyrinth, england, unacceptably, ingenuity, assures,
# Nearest to industrial: industrials, fifty, combined, -stock, anti-climax, rail, mindset, studded,
# Nearest to government: perts, marketed, brushed, notice, scrambled, ramirez, dents, longest-serving,
# Nearest to price: larger-than-expected, dnt-, solemnly, concrete, whipsaw, sticks, pointshigher, offensive,
# Average loss at step  132000 :  2.92960121363
# Average loss at step  134000 :  2.93886327398
# Average loss at step  136000 :  2.90643271059
# Average loss at step  138000 :  2.90723458457
# Average loss at step  140000 :  2.91148530769
# Nearest to higher: rising, lower, per-share, suburbs, ilmited, sport-utility, ultralow, eye-opener,
# Nearest to economic: policysetting, candidacy, unsecured, precursor, upticks, near--point, lets-get-ours-now, pectations,
# Nearest to months: downgraded, years, month, days, wood, elections, silvia, week,
# Nearest to consumer: producer, ammunition, wholesale, weinberg, retail, overtake, slid, atmospheric,
# Nearest to rate: rates, rodriguez, sadly, rale, butwith, executions, militar, kilman,
# Nearest to trading: performances, buoying, pernaps, khedouri, billings, romney, flowing, mitt,
# Nearest to recent: disbelief, preceding, smooths, posed, oracle, automobilesinspired, progrp, schumer,
# Nearest to economists: analysts, observers, forecasters, some, galvanized, chieftains, purported, orchestrated,
# Nearest to rise: drop, increase, fall, climb, decline, retroactive, loss, steadier,
# Nearest to sales: richly, irin, contemplate, endanger, fearful, waged, heavy-duty, substantially,
# Nearest to securities: logically, continuously, select, santomero, remembered, bonds, bond, thoughtful,
# Nearest to reserve: regulators, hist, second-half, perking, exerts, rainy, penfield, tax-selling,
# Nearest to funds: individual, servicer, unacceptably, tradpr, labyrinth, mindspring, thermal, little-known,
# Nearest to industrial: industrials, fifty, combined, -stock, anti-climax, rail, mindset, studded,
# Nearest to government: perts, brushed, marketed, scrambled, notice, ramirez, dents, longest-serving,
# Nearest to price: dnt-, larger-than-expected, concrete, solemnly, sticks, whipsaw, unspecified, offensive,
# Average loss at step  142000 :  2.89190782869
# Average loss at step  144000 :  2.88818569219
# Average loss at step  146000 :  2.87269023454
# Average loss at step  148000 :  2.86962304056
# Average loss at step  150000 :  2.87146334839
# Nearest to higher: rising, lower, per-share, suburbs, ilmited, sport-utility, ultralow, ruin,
# Nearest to economic: policysetting, candidacy, precursor, lets-get-ours-now, near--point, unsecured, pro-gram, pectations,
# Nearest to months: month, downgraded, years, wood, silvia, week, coupons, days,
# Nearest to consumer: producer, ammunition, snappy, retail, slid, weinberg, atmospheric, tax-exempt,
# Nearest to rate: rale, rates, rodriguez, militar, sadly, butwith, astounding, percent,
# Nearest to trading: performances, buoying, pernaps, khedouri, billings, leuthold, mitt, uniformly,
# Nearest to recent: preceding, posed, smooths, disbelief, cloque, confusing, soothed, dichotomy,
# Nearest to economists: analysts, observers, forecasters, chieftains, announces, pictures, purported, orchestrated,
# Nearest to rise: drop, increase, fall, decline, retroactive, climb, brunie, advance,
# Nearest to sales: richly, irin, heavy-duty, contemplate, endanger, waged, fearful, gatnea,
# Nearest to securities: logically, bonds, santomero, continuously, remembered, thoughtful, select, bond,
# Nearest to reserve: hist, dimension, regulators, second-half, tax-selling, questions, exerts, perking,
# Nearest to funds: individual, tradpr, servicer, labyrinth, unacceptably, smaller-scale, home-mortgage, mindspring,
# Nearest to industrial: fifty, industrials, -stock, combined, anti-climax, rail, transportation, mindset,
# Nearest to government: perts, brushed, marketed, notice, scrambled, dents, ramirez, longest-serving,
# Nearest to price: dnt-, larger-than-expected, concrete, whipsaw, sticks, solemnly, above-trend, stretches,
# Average loss at step  152000 :  2.86125978738
# Average loss at step  154000 :  2.8531532039
# Average loss at step  156000 :  2.84045448411
# Average loss at step  158000 :  2.84618483514
# Average loss at step  160000 :  2.83487409568
# Nearest to higher: rising, lower, per-share, suburbs, ilmited, sport-utility, ruin, eye-opener,
# Nearest to economic: policysetting, pectations, precursor, discrimination, near--point, visits, northern, disas,
# Nearest to months: month, downgraded, years, wood, coupons, unhappy, turreted, notch,
# Nearest to consumer: producer, ammunition, retail, overtake, re-examine, wholesale, tax-exempt, slid,
# Nearest to rate: rates, rale, rodriguez, five-tenths, percent, militar, greedy, sadly,
# Nearest to trading: performances, pernaps, buoying, equity-linked, billings, khedouri, mitt, uniformly,
# Nearest to recent: smooths, preceding, posed, oracle, soothed, pretense, disbelief, progrp,
# Nearest to economists: analysts, observers, forecasters, chieftains, some, manufacturing-intensive, galvanized, orchestrated,
# Nearest to rise: drop, increase, fall, retroactive, climb, steadier, decline, loss,
# Nearest to sales: richly, irin, pickup, endanger, octo-ber-to-december, fearful, waged, prices,
# Nearest to securities: logically, remembered, santomero, select, bonds, penney, continuously, dexs,
# Nearest to reserve: regulators, penfield, tax-selling, second-half, resorts, hist, perking, rainy,
# Nearest to funds: individual, tradpr, servicer, labyrinth, unacceptably, smaller-scale, assures, mightiest,
# Nearest to industrial: industrials, fifty, -stock, anti-climax, combined, rail, transportation, liquor,
# Nearest to government: perts, brushed, notice, marketed, ramirez, scrambled, dents, fireworks,
# Nearest to price: dnt-, larger-than-expected, concrete, whipsaw, above-trend, solemnly, sticks, gross-domestic-product,
# Average loss at step  162000 :  2.83634368825
# Average loss at step  164000 :  2.80972806174
# Average loss at step  166000 :  2.81302215266
# Average loss at step  168000 :  2.81846469712
# Average loss at step  170000 :  2.80021484435
# Nearest to higher: lower, rising, per-share, suburbs, ilmited, eye-opener, sport-utility, ruin,
# Nearest to economic: policysetting, visits, export, precursor, pectations, disas, candidacy, pro-gram,
# Nearest to months: month, years, downgraded, wood, week, coupons, turreted, days,
# Nearest to consumer: producer, ammunition, overtake, retail, wholesale, re-examine, recalling, snappy,
# Nearest to rate: rates, rale, five-tenths, rodriguez, percent, butwith, astounding, greedy,
# Nearest to trading: pernaps, performances, buoying, billings, khedouri, uniformly, equity-linked, romney,
# Nearest to recent: smooths, preceding, posed, disbelief, pretense, soothed, copycat, oracle,
# Nearest to economists: analysts, observers, forecasters, chieftains, orchestrated, purported, nakasone, some,
# Nearest to rise: drop, fall, increase, decline, retroactive, climb, rising, loss,
# Nearest to sales: richly, irin, waged, eight-tenths, heavy-duty, gatnea, octo-ber-to-december, contemplate,
# Nearest to securities: logically, santomero, bonds, select, remembered, penney, cutbacks, solving,
# Nearest to reserve: second-half, rainy, resorts, tax-selling, exerts, perking, dimension, penfield,
# Nearest to funds: tradpr, individual, servicer, assures, mindspring, smaller-scale, scrutinizedin, macroprudential,
# Nearest to industrial: combined, fifty, -stock, industrials, anti-climax, rail, transportation, prescribe,
# Nearest to government: perts, brushed, scrambled, marketed, notice, ramirez, dents, energetic,
# Nearest to price: dnt-, larger-than-expected, concrete, sticks, ensure, whipsaw, solemnly, above-trend,
# Average loss at step  172000 :  2.80660497552
# Average loss at step  174000 :  2.77343927944
# Average loss at step  176000 :  2.78455614477
# Average loss at step  178000 :  2.77948913628
# Average loss at step  180000 :  2.77153796422
# Nearest to higher: rising, lower, per-share, suburbs, sport-utility, ilmited, eye-opener, ultralow,
# Nearest to economic: policysetting, appreciable, candidacy, pectations, disas, export, money-supply, discredit,
# Nearest to months: years, month, downgraded, year, wood, days, turreted, empty,
# Nearest to consumer: producer, ammunition, overtake, retail, wholesale, sends, re-examine, recalling,
# Nearest to rate: rates, rodriguez, rale, five-tenths, percent, militar, astounding, greedy,
# Nearest to trading: performances, pernaps, khedouri, equity-linked, buoying, billings, mitt, uniformly,
# Nearest to recent: preceding, smooths, disbelief, posed, pretense, oracle, soothed, shade,
# Nearest to economists: analysts, observers, forecasters, chieftains, purported, orchestrated, some, manufacturing-intensive,
# Nearest to rise: drop, increase, fall, retroactive, rising, climb, decline, steadier,
# Nearest to sales: richly, irin, pickup, waged, endanger, octo-ber-to-december, prices, manage,
# Nearest to securities: logically, bonds, cutbacks, thoughtful, select, santomero, slock, solving,
# Nearest to reserve: hist, rainy, resorts, perking, tax-selling, second-half, dimension, penfield,
# Nearest to funds: servicer, tradpr, individual, smaller-scale, unacceptably, labyrinth, assures, dismantled,
# Nearest to industrial: fifty, industrials, -stock, combined, anti-climax, rail, transportation, four-year-old,
# Nearest to government: perts, marketed, brushed, notice, dents, ramirez, scrambled, indexed,
# Nearest to price: dnt-, larger-than-expected, concrete, above-trend, whipsaw, sticks, solemnly, ensure,
# Average loss at step  182000 :  2.79057400334
# Average loss at step  184000 :  2.74178534168
# Average loss at step  186000 :  2.75340319234
# Average loss at step  188000 :  2.75466489416
# Average loss at step  190000 :  2.73595866042
# Nearest to higher: rising, lower, per-share, suburbs, ultralow, ilmited, landline, ruin,
# Nearest to economic: policysetting, candidacy, precursor, export, discredit, disas, economys, artificially,
# Nearest to months: month, years, downgraded, wood, elections, turreted, billion, nasty,
# Nearest to consumer: producer, ammunition, overtake, wholesale, retail, sends, rolling, recalling,
# Nearest to rate: rates, rale, rodriguez, militar, executions, muggy, five-tenths, sadly,
# Nearest to trading: pernaps, buoying, performances, khedouri, uniformly, closing, equity-linked, flowing,
# Nearest to recent: preceding, smooths, posed, shade, disbelief, oracle, confusing, nine,
# Nearest to economists: analysts, observers, forecasters, chieftains, manufacturing-intensive, nakasone, purported, orchestrated,
# Nearest to rise: drop, increase, fall, retroactive, climb, decline, rising, steadier,
# Nearest to sales: richly, irin, endanger, manage, eight-tenths, heavy-duty, pickup, home-loan,
# Nearest to securities: logically, santomero, cutbacks, select, slock, thoughtful, remembered, bonds,
# Nearest to reserve: second-half, rainy, resorts, hist, tax-selling, emergency-aid, tcongress, penfield,
# Nearest to funds: tradpr, individual, servicer, smaller-scale, unacceptably, dismantled, mightiest, attendance,
# Nearest to industrial: fifty, -stock, combined, anti-climax, industrials, rail, transportation, ucla,
# Nearest to government: perts, marketed, notice, scrambled, brushed, dents, indexed, appealed,
# Nearest to price: dnt-, larger-than-expected, concrete, above-trend, sticks, ensure, stretches, whipsaw,
# Average loss at step  192000 :  2.75270380032
# Average loss at step  194000 :  2.72230962199
# Average loss at step  196000 :  2.72265428668
# Average loss at step  198000 :  2.73260407889
# Average loss at step  200000 :  2.70411172068
# Nearest to higher: rising, lower, per-share, suburbs, ilmited, ultralow, short-circuited, sport-utility,
# Nearest to economic: policysetting, pectations, candidacy, northern, precursor, discredit, upticks, economys,
# Nearest to months: month, years, downgraded, turreted, wood, year, elections, signify,
# Nearest to consumer: producer, ammunition, overtake, wholesale, retail, snappy, sends, recalling,
# Nearest to rate: rale, rates, rodriguez, sadly, militar, butwith, five-tenths, kilman,
# Nearest to trading: pernaps, equity-linked, uniformly, buoying, performances, mitt, khedouri, billings,
# Nearest to recent: posed, preceding, smooths, oracle, soothed, jcome, disbelief, copycat,
# Nearest to economists: analysts, observers, forecasters, purported, chieftains, nakasone, some, orchestrated,
# Nearest to rise: drop, fall, increase, retroactive, rising, steadier, climb, decline,
# Nearest to sales: richly, irin, octo-ber-to-december, manage, long-delayed, prices, pickup, eight-tenths,
# Nearest to securities: logically, cutbacks, select, santomero, remembered, speculate, solving, slock,
# Nearest to reserve: second-half, penfield, ordinarily, exerts, tax-selling, rainy, tcongress, hist,
# Nearest to funds: tradpr, individual, smaller-scale, servicer, unacceptably, mightiest, dismantled, home-mortgage,
# Nearest to industrial: fifty, anti-climax, -stock, combined, industrials, transportation, rail, coalition,
# Nearest to government: perts, brushed, notice, marketed, scrambled, indexed, dents, allowing,
# Nearest to price: dnt-, larger-than-expected, concrete, sticks, ensure, above-trend, stretches, whipsaw,
# Average loss at step  202000 :  2.73815956408
# Average loss at step  204000 :  2.69364810222
# Average loss at step  206000 :  2.69392908776
# Average loss at step  208000 :  2.71732775921
# Average loss at step  210000 :  2.67621474415
# Nearest to higher: rising, per-share, lower, suburbs, ultralow, eye-opener, sport-utility, ilmited,
# Nearest to economic: policysetting, pectations, precursor, northern, candidacy, debates, discredit, visits,
# Nearest to months: month, years, downgraded, signify, turreted, elections, wood, inflows,
# Nearest to consumer: producer, ammunition, overtake, retail, sends, placated, snappy, wholesale,
# Nearest to rate: rodriguez, rates, rale, five-tenths, sadly, percent, greedy, realty,
# Nearest to trading: pernaps, equity-linked, performances, uniformly, mitt, buoying, khedouri, billings,
# Nearest to recent: smooths, posed, preceding, soothed, disbelief, progrp, copycat, pretense,
# Nearest to economists: analysts, observers, forecasters, some, chieftains, orchestrated, galvanized, nakasone,
# Nearest to rise: drop, increase, fall, decline, rising, retroactive, run-up, steadier,
# Nearest to sales: irin, manage, octo-ber-to-december, richly, endanger, pickup, volumo, heavy-duty,
# Nearest to securities: logically, cutbacks, santomero, select, remembered, kemp, speculate, dexs,
# Nearest to reserve: rainy, resorts, second-half, exerts, tax-selling, evolved, hist, penfield,
# Nearest to funds: tradpr, servicer, individual, mightiest, smaller-scale, unacceptably, macroprudential, goods,
# Nearest to industrial: anti-climax, -stock, fifty, combined, industrials, rail, transportation, prescribe,
# Nearest to government: perts, brushed, notice, marketed, ramirez, scrambled, dents, appealed,
# Nearest to price: larger-than-expected, dnt-, concrete, above-trend, portends, stretches, behind, prices,
# Average loss at step  212000 :  2.70886544031
# Average loss at step  214000 :  2.66537428442
# Average loss at step  216000 :  2.66831224817
# Average loss at step  218000 :  2.68899120206
# Average loss at step  220000 :  2.65486915892
# Nearest to higher: rising, lower, per-share, suburbs, ilmited, ruin, eye-opener, vied,
# Nearest to economic: pectations, candidacy, policysetting, export, magnitude, thejanuary-july, disas, debates,
# Nearest to months: years, downgraded, month, turreted, signify, inflows, take-off, days,
# Nearest to consumer: producer, ammunition, overtake, sends, wholesale, retail, snappy, recalling,
# Nearest to rate: rates, rodriguez, rale, five-tenths, percent, sadly, greedy, butwith,
# Nearest to trading: pernaps, uniformly, performances, mitt, equity-linked, buoying, khedouri, leuthold,
# Nearest to recent: smooths, preceding, posed, disbelief, progrp, pretense, sniff, oracle,
# Nearest to economists: analysts, observers, forecasters, chieftains, some, orchestrated, manufacturing-intensive, galvanized,
# Nearest to rise: drop, increase, rising, decline, fall, retroactive, steadier, studios,
# Nearest to sales: octo-ber-to-december, irin, richly, hamper, long-delayed, pickup, endanger, manage,
# Nearest to securities: logically, select, santomero, cutbacks, dexs, remembered, levelling, slock,
# Nearest to reserve: rainy, resorts, hist, tighten, penfield, perking, tax-selling, cac-,
# Nearest to funds: tradpr, individual, servicer, unacceptably, smaller-scale, mightiest, agoniz-i, attendance,
# Nearest to industrial: anti-climax, fifty, -stock, combined, industrials, rail, coalition, transportation,
# Nearest to government: perts, brushed, notice, scrambled, marketed, dents, ramirez, indexed,
# Nearest to price: larger-than-expected, dnt-, stretches, concrete, sticks, above-trend, ensure, causing,
# Average loss at step  222000 :  2.6920256283
# Average loss at step  224000 :  2.64620600247
# Average loss at step  226000 :  2.65446881163
# Average loss at step  228000 :  2.66375720781
# Average loss at step  230000 :  2.63800502765
# Nearest to higher: rising, lower, per-share, eye-opener, suburbs, ilmited, ruin, short-circuited,
# Nearest to economic: pectations, disas, policysetting, precursor, candidacy, magnitude, economys, debates,
# Nearest to months: month, years, downgraded, turreted, wood, days, nasty, elections,
# Nearest to consumer: producer, ammunition, overtake, sends, wholesale, capability, retail, pushes,
# Nearest to rate: rates, rale, rodriguez, business-sector, butwith, sadly, muggy, five-tenths,
# Nearest to trading: pernaps, mitt, khedouri, uniformly, performances, equity-linked, commemorate, buoying,
# Nearest to recent: smooths, posed, disbelief, last, oracle, preceding, pretense, copycat,
# Nearest to economists: analysts, observers, forecasters, chieftains, some, galvanized, manufacturing-intensive, announces,
# Nearest to rise: drop, increase, decline, fall, retroactive, rising, run-up, steadier,
# Nearest to sales: octo-ber-to-december, endanger, richly, prices, pickup, irin, fills, hamper,
# Nearest to securities: logically, bonds, select, santomero, cutbacks, levelling, speculate, remembered,
# Nearest to reserve: resorts, rainy, exerts, tighten, tax-selling, dimension, hist, evolved,
# Nearest to funds: tradpr, individual, servicer, smaller-scale, attendance, little-known, mightiest, mend,
# Nearest to industrial: anti-climax, combined, fifty, -stock, industrials, coalition, transportation, cluijted,
# Nearest to government: perts, brushed, dents, notice, scrambled, indexed, marketed, limit,
# Nearest to price: larger-than-expected, dnt-, concrete, prices, stretches, bureaucracy-building, ensure, causing,
# Average loss at step  232000 :  2.66676762617
# Average loss at step  234000 :  2.62289876932
# Average loss at step  236000 :  2.61363955957
# Average loss at step  238000 :  2.64570754355
# Average loss at step  240000 :  2.61773071223
# Nearest to higher: rising, lower, per-share, suburbs, eye-opener, ilmited, ruin, shuffled,
# Nearest to economic: export, upticks, debates, policysetting, magnitude, discrimination, candidacy, precursor,
# Nearest to months: month, years, downgraded, turreted, elections, days, junes, year,
# Nearest to consumer: producer, ammunition, overtake, wholesale, re-examine, sends, recalling, retail,
# Nearest to rate: rates, rodriguez, rale, five-tenths, militar, sadly, business-sector, greedy,
# Nearest to trading: pernaps, mitt, uniformly, performances, khedouri, commemorate, equity-linked, buoying,
# Nearest to recent: smooths, oracle, posed, preceding, disbelief, pretense, reignite, confusing,
# Nearest to economists: analysts, observers, forecasters, chieftains, some, purported, orchestrated, manufacturing-intensive,
# Nearest to rise: drop, increase, decline, fall, retroactive, rising, advance, steadier,
# Nearest to sales: irin, richly, octo-ber-to-december, hamper, prices, long-delayed, manage, endanger,
# Nearest to securities: logically, santomero, select, bonds, slock, cutbacks, thoughtful, bond,
# Nearest to reserve: rainy, exerts, tighten, tax-selling, cac-, resorts, penfield, delta,
# Nearest to funds: tradpr, individual, servicer, smaller-scale, mend, mightiest, legally, etfs,
# Nearest to industrial: anti-climax, -stock, fifty, industrials, combined, coalition, cluijted, rail,
# Nearest to government: perts, brushed, dents, notice, scrambled, marketed, cheering, re-stimulate,
# Nearest to price: larger-than-expected, dnt-, concrete, stretches, ensure, above-trend, bureaucracy-building, sticks,
# Average loss at step  242000 :  2.63630158734
# Average loss at step  244000 :  2.61227878964
# Average loss at step  246000 :  2.59899818319
# Average loss at step  248000 :  2.6184320522
# Average loss at step  250000 :  2.60498313558
# Nearest to higher: rising, lower, per-share, suburbs, eye-opener, ilmited, ruin, ultralow,
# Nearest to economic: policysetting, pectations, debates, candidacy, export, magnitude, artificially, economy,
# Nearest to months: month, years, downgraded, turreted, thirty-sixth, elections, billion, turnabouts,
# Nearest to consumer: producer, ammunition, overtake, sends, rolling, recalling, re-examine, pushes,
# Nearest to rate: rates, rale, rodriguez, executions, five-tenths, percent, militar, muggy,
# Nearest to trading: pernaps, uniformly, khedouri, commemorate, performances, mitt, equity-linked, leuthold,
# Nearest to recent: posed, smooths, oracle, preceding, last, disbelief, pretense, reignite,
# Nearest to economists: analysts, observers, forecasters, purported, peo-, orchestrated, chieftains, announces,
# Nearest to rise: drop, increase, fall, decline, retroactive, rising, climb, steadier,
# Nearest to sales: irin, prices, richly, hamper, octo-ber-to-december, volumo, long-delayed, heavy-duty,
# Nearest to securities: logically, santomero, select, cutbacks, levelling, slock, thoughtful, dexs,
# Nearest to reserve: tighten, tax-selling, exerts, penfield, cac-, rainy, resorts, veward,
# Nearest to funds: tradpr, smaller-scale, individual, servicer, mindspring, mightiest, labyrinth, interpret,
# Nearest to industrial: -stock, anti-climax, fifty, combined, industrials, coalition, rail, liquor,
# Nearest to government: perts, dents, brushed, notice, limit, scrambled, yesterday, cheering,
# Nearest to price: larger-than-expected, dnt-, concrete, stretches, above-trend, bureaucracy-building, whipsaw, ensure,
# Average loss at step  252000 :  2.62715186161
# Average loss at step  254000 :  2.60015372789
# Average loss at step  256000 :  2.58891478044
# Average loss at step  258000 :  2.59861853957
# Average loss at step  260000 :  2.57978205878
# Nearest to higher: rising, lower, per-share, suburbs, eye-opener, ilmited, ruin, sport-utility,
# Nearest to economic: candidacy, precursor, pectations, upticks, magnitude, export, disas, debates,
# Nearest to months: month, years, downgraded, turnabouts, junes, nasty, thirty-sixth, bobbed,
# Nearest to consumer: producer, ammunition, overtake, retail, sends, pushes, lightly, placated,
# Nearest to rate: rates, rale, rodriguez, sadly, cent, five-tenths, militar, greedy,
# Nearest to trading: pernaps, uniformly, mitt, performances, equity-linked, khedouri, deitedjtarkets, flowing,
# Nearest to recent: smooths, posed, pretense, preceding, oracle, disbelief, reignite, confusing,
# Nearest to economists: analysts, observers, forecasters, nakasone, purported, chieftains, manufacturing-intensive, some,
# Nearest to rise: drop, increase, decline, fall, retroactive, run-up, decrease, steadier,
# Nearest to sales: irin, octo-ber-to-december, prices, hamper, manage, long-delayed, pickup, home-loan,
# Nearest to securities: logically, cutbacks, santomero, select, levelling, dexs, slock, speculate,
# Nearest to reserve: rainy, resorts, tighten, tax-selling, exerts, hist, veward, dimension,
# Nearest to funds: tradpr, individual, smaller-scale, mightiest, unacceptably, goods, servicer, labyrinth,
# Nearest to industrial: -stock, anti-climax, fifty, combined, coalition, liquor, transportation, andres,
# Nearest to government: perts, notice, brushed, dents, cheering, employment, repairs, scrambled,
# Nearest to price: larger-than-expected, dnt-, ensure, stretches, above-trend, concrete, pegged, causing,
# Average loss at step  262000 :  2.60382187724
# Average loss at step  264000 :  2.57816201586
# Average loss at step  266000 :  2.57261009628
# Average loss at step  268000 :  2.58317595911
# Average loss at step  270000 :  2.56676492637
# Nearest to higher: rising, lower, per-share, ruin, eye-opener, ilmited, suburbs, sport-utility,
# Nearest to economic: pectations, export, candidacy, precursor, magnitude, debates, contesting, pointfrom,
# Nearest to months: years, month, downgraded, week, turreted, limp, thirty-sixth, turnabouts,
# Nearest to consumer: ammunition, producer, overtake, retail, lightly, placated, sends, columbias,
# Nearest to rate: rates, rodriguez, rale, five-tenths, cent, greedy, butwith, executions,
# Nearest to trading: pernaps, uniformly, mitt, equity-linked, khedouri, commemorate, farming, pomt,
# Nearest to recent: smooths, oracle, pretense, disbelief, preceding, posed, soothed, reignite,
# Nearest to economists: analysts, forecasters, observers, purported, nakasone, announces, chieftains, laggards,
# Nearest to rise: drop, decline, increase, fall, decrease, retroactive, asset-purchase, brunie,
# Nearest to sales: octo-ber-to-december, irin, prices, richly, pickup, long-delayed, volumo, hamper,
# Nearest to securities: logically, select, cutbacks, continuously, slock, levelling, santomero, speculate,
# Nearest to reserve: tighten, tax-selling, ordinarily, resorts, veward, rainy, hist, penfield,
# Nearest to funds: tradpr, smaller-scale, servicer, scrutinizedin, mindspring, individual, mend, unacceptably,
# Nearest to industrial: anti-climax, -stock, fifty, combined, coalition, transportation, rail, industrials,
# Nearest to government: perts, dents, brushed, notice, cheering, limit, troubles, employment,
# Nearest to price: larger-than-expected, dnt-, prices, ensure, above-trend, concrete, causing, behind,
# Average loss at step  272000 :  2.57940670049
# Average loss at step  274000 :  2.56449723583
# Average loss at step  276000 :  2.56422755229
# Average loss at step  278000 :  2.55912286958
# Average loss at step  280000 :  2.56322790778
# Nearest to higher: rising, lower, per-share, eye-opener, ruin, suburbs, drop, ilmited,
# Nearest to economic: pectations, subconscious, export, candidacy, fluctuation, debates, rockwells, fleeced,
# Nearest to months: years, month, downgraded, wood, turnabouts, coupons, thirty-sixth, elections,
# Nearest to consumer: producer, ammunition, overtake, retail, sends, pushes, columbias, llth,
# Nearest to rate: rates, rodriguez, rale, executions, percent, militar, partisanship, muggy,
# Nearest to trading: pernaps, uniformly, mitt, khedouri, equity-linked, deitedjtarkets, commemorate, closing,
# Nearest to recent: posed, oracle, smooths, disbelief, preceding, pretense, confusing, fueled,
# Nearest to economists: analysts, observers, forecasters, nakasone, purported, chieftains, announces, mccarthy,
# Nearest to rise: drop, increase, decline, retroactive, fall, decrease, run-up, loss,
# Nearest to sales: long-delayed, prices, octo-ber-to-december, establishments, hamper, pickup, manage, irin,
# Nearest to securities: logically, select, santomero, speculate, remembered, slock, technology-oriented, levelling,
# Nearest to reserve: tighten, exerts, rainy, penfield, veward, cac-, hist, resorts,
# Nearest to funds: tradpr, smaller-scale, servicer, individual, mend, t-style, scrutinizedin, attendance,
# Nearest to industrial: anti-climax, -stock, fifty, combined, andres, coalition, transportation, liquor,
# Nearest to government: perts, notice, brushed, dents, limit, scrambled, indexed, cheering,
# Nearest to price: larger-than-expected, dnt-, ensure, above-trend, prices, behind, bureaucracy-building, stretches,
# Average loss at step  282000 :  2.55796799034
# Average loss at step  284000 :  2.5438449223
# Average loss at step  286000 :  2.54786265677
# Average loss at step  288000 :  2.53696273065
# Average loss at step  290000 :  2.55520957983
# Nearest to higher: rising, lower, per-share, eye-opener, ruin, ilmited, suburbs, drop,
# Nearest to economic: pectations, candidacy, policysetting, export, debates, fluctuation, pointfrom, precursor,
# Nearest to months: years, month, nasty, thirty-sixth, downgraded, folded, bobbed, week,
# Nearest to consumer: producer, ammunition, overtake, retail, sends, snappy, pushes, lightly,
# Nearest to rate: rates, rodriguez, rale, five-tenths, militar, butwith, muggy, executions,
# Nearest to trading: pernaps, uniformly, mitt, equity-linked, khedouri, performances, closing, farming,
# Nearest to recent: smooths, posed, oracle, preceding, disbelief, confusing, pretense, consummate,
# Nearest to economists: analysts, forecasters, observers, chieftains, purported, nakasone, announces, some,
# Nearest to rise: drop, increase, decline, retroactive, fall, decrease, rising, loss,
# Nearest to sales: irin, richly, endanger, pickup, hamper, octo-ber-to-december, establishments, manage,
# Nearest to securities: logically, select, slock, cutbacks, levelling, santomero, dexs, speculate,
# Nearest to reserve: tighten, hist, exerts, veward, tax-selling, penfield, rainy, cac-,
# Nearest to funds: tradpr, smaller-scale, mend, first-ever, servicer, little-known, nfib, individual,
# Nearest to industrial: anti-climax, -stock, coalition, fifty, combined, transportation, andres, industrials,
# Nearest to government: perts, brushed, notice, scrambled, dents, indexed, limit, fireworks,
# Nearest to price: larger-than-expected, dnt-, prices, above-trend, ensure, concrete, stretches, underway,
# Average loss at step  292000 :  2.53581237155
# Average loss at step  294000 :  2.52999109167
# Average loss at step  296000 :  2.52623327297
# Average loss at step  298000 :  2.52403345424

# %%
with open('word-list.p', 'wb') as fopen:
    pickle.dump(list(reverse_dictionary.values()), fopen, protocol=2)

# %%
with open('vector.p', 'wb') as fopen:
    pickle.dump(final_embeddings, fopen, protocol=2)
